# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('PragueAirBnB.csv',sep=';')
df.head(5)
# Out:
#     Room ID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews Date last review  Number of reviews per month  \
# 0                 79       2020-06-23                         3.09
# ...

# %%
df.rename({'Room ID':'RoomID'}, axis = 1, inplace=True)
df
# Out:
#          RoomID                                               Name     HostID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
df.RoomID.nunique()
# Out:
# 12565

# %%
df.info
# Out:
# <bound method DataFrame.info of          RoomID                                               Name    Host ID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
df.head(15)
# Out:
#       RoomID                                               Name    Host ID  \
# 0   25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1   25197350      Room in beautiful area close to Prague Castle   28365945
# 2   25470062           Luxury apartment in the center of Prague   47717433
# 3   25547218        Much More For Your Money In Beautiful Letná   21217319
# 4   25907826    Apartment near city transport and Prague center  119497941
# 5   25989382  Apartment Prague -Sunny flat with air conditio...    1629431
# 6   26148293   City Center Apartm. in Prague with balcony - no2   67170748
# 7   26150119   Flamingo apartment 3 bedrooms and shared kitchen   22608410
# 8   26188305   New OLD TOWN SQUARE Ap. next CHRISTMAS MARKETS⭐️  128620302
# 9   26224498                                    Room at Andel 3  112997712
# 10  26298622  MiniHouse,quiet suburb/35min center, fare disc...  126722619
# ...

# %%
df[['Latitude','Longtitude']] = df.Coordinates.str.split(',', expand=True)
df = df.drop('Coordinates', axis=1)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-03d05ba00159> in <module>
# ----> 1 df[['Latitude','Longtitude']] = df.Coordinates.str.split(',', expand=True)
#       2 df = df.drop('Coordinates', axis=1)
#       3 df.head(5)
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Coordinates'

# %%
df['Name'] = df['Name'].fillna('-')
df.isnull().sum()
# Out:
# RoomID           0
# Name             0
# HostID           0
# Neighbourhood    0
# RoomType         0
# Price            0
# MinNights        0
# NumReviews       0
# RoomsPerHost     0
# Availibility     0
# Location         0
# Latitude         0
# Longtitude       0
# PriceCategory    0
# dtype: int64

# %%
df.head(5)
# Out:
#      RoomID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews Date last review  Number of reviews per month  \
# 0                 79       2020-06-23                         3.09
# ...

# %%
df = df.drop('Date last review', axis=1)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-191070b4555f> in <module>
# ----> 1 df = df.drop('Date last review', axis=1)
#       2 df.head(5)
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df = df.drop('Number of reviews per month', axis=1)
df.head(5)
# Out:
#      RoomID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews  Rooms rent by the host  Availibility Updated Date  \
# 0                 79                       1           172   2020-06-28
# ...

# %%
df.head(5)
# Out:
#      RoomID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews  Rooms rent by the host  Availibility Updated Date  \
# 0                 79                       1           172   2020-06-28
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-1904ad50acdf> in <module>
#      10
#      11 )
# ---> 12 fig.write_image("table_plotly.png", scale=1)
#      13 fig.show()
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\plotly\basedatatypes.py in write_image(self, *args, **kwargs)
#    3804         import plotly.io as pio
#    3805
# -> 3806         return pio.write_image(self, *args, **kwargs)
#    3807
#    3808     # Static helpers
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\plotly\io\_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     250         height=height,
#     251         validate=validate,
# --> 252         engine=engine,
#     253     )
#     254
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\plotly\io\_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          RoomID                                               Name    Host ID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
df.head(5)

# %%
df = df.drop('Updated Date', axis=1)
df.head(5)
# Out:
#      RoomID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews  Rooms rent by the host  Availibility    City  \
# 0                 79                       1           172  Prague
# ...

# %%
df['Neighbourhood'].unique()
# Out:
# array(['Praha 3', 'Praha 6', 'Praha 2', 'Praha 7', 'Praha 4', 'Praha 5',
#        'Praha 1', 'Praha 13', 'Praha 9', 'Praha 10', 'Čakovice',
#        'Praha 8', 'Benice', 'Praha 22', 'Libuš', 'Praha 11', 'Troja',
#        'Újezd', 'Přední Kopanina', 'Praha 14', 'Praha 12', 'Zličín',
#        'Petrovice', 'Praha 18', 'Dolní Počernice', 'Zbraslav', 'Praha 20',
#        'Praha 17', 'Dolní Chabry', 'Lipence', 'Běchovice', 'Praha 15',
#        'Praha 21', 'Kunratice', 'Nebušice', 'Klánovice', 'Řeporyje',
#        'Suchdol', 'Dolní Měcholupy', 'Satalice', 'Ďáblice',
#        'Velká Chuchle', 'Březiněves', 'Štěrboholy', 'Šeberov', 'Vinoř',
#        'Slivenec', 'Kolovraty', 'Praha 19', 'Praha 16', 'Koloděje',
#        'Královice', 'Lysolaje'], dtype=object)

# %%
df.dtypes

# %%
df['Room type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
df = df.drop('City', axis=1)
df.head(5)
# Out:
#      RoomID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews  Rooms rent by the host  Availibility         Country  \
# 0                 79                       1           172  Czech republic
# ...

# %%
df = df.drop('Country', axis=1)
df.head(5)
# Out:
#      RoomID                                             Name    Host ID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood        Room type  Room Price  Minimum nights  \
# 0       Praha 3  Entire home/apt        1310               1
# 1       Praha 6     Private room         763               1
# 2       Praha 2  Entire home/apt        1071               2
# 3       Praha 7  Entire home/apt        2074               1
# 4       Praha 4  Entire home/apt        2504               1
#
#    Number of reviews  Rooms rent by the host  Availibility  \
# 0                 79                       1           172
# ...

# %%
df.rename({'Host ID':'HostID'}, axis = 1, inplace=True)
df
# Out:
#          RoomID                                               Name     HostID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
df.rename({'Room type':'RoomType'}, axis = 1, inplace=True)

# %%
df.rename({'Room Price':'Price'}, axis = 1, inplace=True)

# %%
df.rename({'Minimum nights':'MinNights'}, axis = 1, inplace=True)
df
# Out:
#          RoomID                                               Name     HostID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
df.rename({'Number of reviews':'NumReviews'}, axis = 1, inplace=True)
df
# Out:
#          RoomID                                               Name     HostID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
df.rename({'Rooms rent by the host':'RoomsPerHost'}, axis = 1, inplace=True)
df
# Out:
#          RoomID                                               Name     HostID  \
# 0      25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1      25197350      Room in beautiful area close to Prague Castle   28365945
# 2      25470062           Luxury apartment in the center of Prague   47717433
# 3      25547218        Much More For Your Money In Beautiful Letná   21217319
# 4      25907826    Apartment near city transport and Prague center  119497941
# ...         ...                                                ...        ...
# 12560  24505506   Enjoy Prague in cosy 1-BR apt with fine services    9320685
# 12561  24533820  Wenceslas Square / Main Station Apt in 19th Ce...   34362547
# 12562  24548667                                       Byt Albertov  102121859
# 12563  24773178              Prague's Rainbow Guest House - Luxury  180513505
# 12564  24973023                               612/1 Blue apartment  167129603
#
# ...

# %%
import plotly.graph_objects as go


dfTable = df.head(4)

fig = go.Figure(data=[go.Table(
    columnwidth=[70,100,70,70,60,40,60,70,70,70,70,93,93],
    header=dict(values=list(dfTable.columns),
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[dfTable.RoomID,dfTable.Name,dfTable.HostID,dfTable.Neighbourhood,dfTable.RoomType,dfTable.Price,
                       dfTable.MinNights,dfTable.NumReviews,dfTable.RoomsPerHost
                      ,dfTable.Availibility,dfTable.Location,dfTable.Latitude,dfTable.Longtitude],
               fill_color='lavender',
               align='left'))
])
fig.update_layout(
   
    width=1320,
   
    
)
fig.write_image("cleanedTable.png", scale=1)
fig.show()

# %%
df.dtypes

# %%
df.head(5)

# %%
df['Latitude'] = df.Latitude.astype(float)
df.dtypes
# Out:
# RoomID             int64
# Name              object
# HostID             int64
# Neighbourhood     object
# RoomType          object
# Price              int64
# MinNights          int64
# NumReviews         int64
# RoomsPerHost       int64
# Availibility       int64
# Location          object
# Latitude         float64
# Longtitude        object
# dtype: object

# %%
df['Longtitude'] = df.Longtitude.astype(float)
df.dtypes
# Out:
# RoomID             int64
# Name              object
# HostID             int64
# Neighbourhood     object
# RoomType          object
# Price              int64
# MinNights          int64
# NumReviews         int64
# RoomsPerHost       int64
# Availibility       int64
# Location          object
# Latitude         float64
# Longtitude       float64
# dtype: object

# %%
lower_bound = .25
upper_bound = .75
iqr = df[df['Price'].between(df['Price'].quantile(lower_bound), df['Price'].quantile(upper_bound), inclusive=True)]
priceData = iqr.copy()
desc = priceData.describe()
desc.loc['skew'] = desc.skew()
desc.loc['skew'] = desc.kurt()
pd.set_option('display.float_format', lambda x: '%.5f' % x)
desc

# %%
df.Price.describe()
# Out:
# count     12565.000000
# mean       3635.900915
# std       15277.950644
# min           0.000000
# 25%         952.000000
# 50%        1476.000000
# 75%        2504.000000
# max      267448.000000
# Name: Price, dtype: float64

# %%
priceCat = pd.qcut(df['Price'], 4,  labels=['nízká', 'střední', 'vysoká', 'nejvyšší'])

# %%
priceCat
# Out:
# 0        střední
# 1          nízká
# 2        střední
# 3         vysoká
# 4         vysoká
#           ...
# 12560    střední
# 12561     vysoká
# 12562      nízká
# 12563      nízká
# 12564     vysoká
# Name: Price, Length: 12565, dtype: category
# Categories (4, object): ['nízká' < 'střední' < 'vysoká' < 'nejvyšší']

# %%
df['PriceCategory'] = priceCat

# %%
df.head(30)
# Out:
#       RoomID                                               Name     HostID  \
# 0   25092602     ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1   25197350      Room in beautiful area close to Prague Castle   28365945
# 2   25470062           Luxury apartment in the center of Prague   47717433
# 3   25547218        Much More For Your Money In Beautiful Letná   21217319
# 4   25907826    Apartment near city transport and Prague center  119497941
# 5   25989382  Apartment Prague -Sunny flat with air conditio...    1629431
# 6   26148293   City Center Apartm. in Prague with balcony - no2   67170748
# 7   26150119   Flamingo apartment 3 bedrooms and shared kitchen   22608410
# 8   26188305   New OLD TOWN SQUARE Ap. next CHRISTMAS MARKETS⭐️  128620302
# 9   26224498                                    Room at Andel 3  112997712
# 10  26298622  MiniHouse,quiet suburb/35min center, fare disc...  126722619
# ...

# %%
df.to_csv('ReadyPragAirBnB.csv', sep=';')

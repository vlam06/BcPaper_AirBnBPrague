# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from keras import Sequential
from keras import layers
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import tensorflow as tf
import os
import collections

def RMSE(Y,YHAT):
    return np.sqrt(mean_squared_error(Y,YHAT))
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

df = pd.read_csv('ReadyPragAirBnB.csv',sep=';', index_col=0)
df.head(5)
# Out:
#      RoomID                                             Name     HostID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood         RoomType  Price  MinNights  NumReviews  RoomsPerHost  \
# 0       Praha 3  Entire home/apt   1310          1          79             1
# 1       Praha 6     Private room    763          1           2             1
# 2       Praha 2  Entire home/apt   1071          2          84             1
# 3       Praha 7  Entire home/apt   2074          1          21             1
# 4       Praha 4  Entire home/apt   2504          1          16             1
#
#    Availibility                         Location   Latitude  Longtitude  \
# 0           172  Czech republic, Prague, Praha 3  50.086376   14.444495
# 1             0  Czech republic, Prague, Praha 6  50.083104   14.369196
# 2           109  Czech republic, Prague, Praha 2  50.073298   14.439128
# 3             0  Czech republic, Prague, Praha 7  50.102008   14.417981
# 4             0  Czech republic, Prague, Praha 4  50.057750   14.450172
#
#   PriceCategory
# 0         nízká
# 1         nízká
# 2         nízká
# 3       střední
# 4       střední

# %%
vocab = collections.Counter(' '.join(df['Name']).split(' '))


MAX_LENGTH = max(df['Name'].apply(lambda x: len(x)))
VOCAB_SIZE = len(vocab.keys())
VECTOR_SPACE = 100

encoded_docs = [tf.keras.preprocessing.text.one_hot(d,VOCAB_SIZE) for d in df.Name]

padded_docs = tf.keras.preprocessing.sequence.pad_sequences(encoded_docs,maxlen=MAX_LENGTH,padding='post')

padded_docs_eval = padded_docs[0:1000]
padded_docs = padded_docs[1000:]
Y = df.Price[1000:]
Y_eval = df.Price[:1000]

# %%
FCNN_MODEL = Sequential([
    tf.keras.layers.Embedding(VOCAB_SIZE,VECTOR_SPACE,input_length=MAX_LENGTH),
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(activation='relu',units=5), 
    tf.keras.layers.Dense(activation='relu',units=1)
    
   
])

FCNN_MODEL.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-52e5acfa2529> in <module>
#       4
#       5     tf.keras.layers.Dense(activation='relu',units=5),
# ----> 6     tf.keras.layers.Dense(activation='relu',units=1)
#       7
#       8
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\keras\engine\sequential.py in __init__(self, layers, name)
#      92         if layers:
#      93             for layer in layers:
# ---> 94                 self.add(layer)
#      95
#      96     @property
#
# ~\anaconda3\envs\bpEnv\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     131             raise TypeError('The added layer must be '
#     132                             'an instance of class Layer. '
# --> 133                             'Found: ' + str(layer))
#     134         self.built = False
#     135         if not self._layers:
#
# TypeError: The added layer must be an instance of class Layer. Found: <tensorflow.python.keras.layers.embeddings.Embedding object at 0x000001E45E52D808>

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
##Lineární regrese
lrDf = pd.DataFrame(data=df)
lrDf.drop(['Name','RoomID','Location','PriceCategory'],axis=1,inplace=True)




le = preprocessing.LabelEncoder()
le.fit(df['Neighbourhood'])
lrDf['Neighbourhood']=le.transform(lrDf['Neighbourhood'])

le = preprocessing.LabelEncoder()
le.fit(lrDf['RoomType'])
lrDf['RoomType']=le.transform(lrDf['RoomType'])

lrDf.sort_values(by='Price',ascending=True,inplace=True)

lrDf.head()
# Out:
#          HostID  Neighbourhood  RoomType  Price  MinNights  NumReviews  \
# 175   311957181             27         1      0          1           0
# 1511  304235499             36         1      0          1           0
# 3280  311984646             33         1      0          1           0
# 5723  311953210             27         1      0          1           0
# 2630  119088430             20         3     24          1           0
#
#       RoomsPerHost  Availibility   Latitude  Longtitude
# 175              1             0  50.074422   14.430424
# 1511             1             0  50.095081   14.453803
# 3280             1             0  50.069834   14.410105
# 5723             1             0  50.072518   14.429431
# 2630             1             0  50.050168   14.347674

# %%
lm = LinearRegression()

X = lrDf[['Neighbourhood','Latitude','Longtitude','RoomType','MinNights','NumReviews','RoomsPerHost','Availibility']]
y = lrDf['Price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predicts = lm.predict(X_test)
error_airbnb = pd.DataFrame({
        'ActualValues': np.array(y_test).flatten(),
        'PredictedValues': predicts.flatten()})
error_airbnb.head(30)
# Out:
#     ActualValues  PredictedValues
# 0            952      1854.136974
# 1           1407      2750.131385
# 2            690      3393.824243
# 3           8893      3382.588389
# 4          12024      5063.038836
# 5           1881      6231.278383
# 6           1357      6996.622206
# 7            500      1212.866359
# 8           1192      1602.743775
# 9           1190      1002.670321
# 10          2476      8028.902515
# 11          9357      7243.740062
# 12          1071      2677.818136
# 13          1881      5634.573196
# 14          1071      2320.447004
# 15          2667      4494.716293
# 16          1192      2453.464974
# 17          3004      6007.987316
# 18           619      3275.858888
# 19           762      1976.587396
# 20          1119      2028.687201
# 21          4006      2490.607014
# 22          2289      4505.966567
# 23          1190      3557.860081
# 24           787       901.473075
# 25          2143      7155.203034
# 26           786      2224.534670
# 27          1333      3775.187749
# 28          2595      4650.424640
# 29           714      2708.397051

# %%
rmse = np.sqrt(np.mean(predicts - y_test)**2)
print('rmse: ', rmse)

r2 = r2_score(error_airbnb.ActualValues, error_airbnb.PredictedValues)
print('r2 score: ', r2)
# Out:
# rmse:  523.5801975215502
# r2 score:  0.00965451383655791

# %%
limitedDf = lrDf[lrDf.Price < 15000]
limitedDf.head(5)
# Out:
#          HostID  Neighbourhood  RoomType  Price  MinNights  NumReviews  \
# 175   311957181             27         1      0          1           0
# 1511  304235499             36         1      0          1           0
# 3280  311984646             33         1      0          1           0
# 5723  311953210             27         1      0          1           0
# 2630  119088430             20         3     24          1           0
#
#       RoomsPerHost  Availibility   Latitude  Longtitude
# 175              1             0  50.074422   14.430424
# 1511             1             0  50.095081   14.453803
# 3280             1             0  50.069834   14.410105
# 5723             1             0  50.072518   14.429431
# 2630             1             0  50.050168   14.347674

# %%
lm = LinearRegression()

X = limitedDf[['HostID','Neighbourhood','Latitude','Longtitude','RoomType','MinNights','NumReviews','RoomsPerHost','Availibility']]
y = limitedDf['Price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predicts = lm.predict(X_test)
lrPred = pd.DataFrame({
        'ActualValues': np.array(y_test).flatten(),
        'PredictedValues': predicts.flatten()})
lrPred.head(30)
# Out:
#     ActualValues  PredictedValues
# 0            238      1465.306314
# 1           1357      2471.841189
# 2           2691      4659.378833
# 3          10396      3322.324623
# 4           1071      1635.026238
# 5           1024      1729.292348
# 6           2599      1733.691827
# 7            500       758.002002
# 8           1333      3275.419500
# 9           4268      2059.768477
# 10         13357      2738.065404
# 11          1311      1916.930150
# 12          9881      1750.097522
# 13           524      3208.765644
# 14          1335      2317.918149
# 15          1119        26.958852
# 16          4548      2051.382109
# 17          2048      2442.422136
# 18           500      1143.983662
# 19          5000      4761.700246
# 20          4000      3051.885361
# 21          2691      3362.257178
# 22          1810      2936.897754
# 23          2143      1101.631802
# 24          2429      2044.731122
# 25          2405      3424.901843
# 26           644      1798.261788
# 27          1884      1707.158125
# 28          1190      2677.790564
# 29          1192      1469.865337

# %%
rmse = np.sqrt(np.mean(predicts - y_test)**2)
print('rmse: ', rmse)

r2 = r2_score(lrPred.ActualValues, lrPred.PredictedValues)
print('r2 score: ', r2)
# Out:
# rmse:  41.322828375619565
# r2 score:  0.13858189192513537

# %%
import seaborn as sns
sns.residplot(x=lrPred['Actual Values'],y=lrPred['Predicted Values'])
# Out:
# <AxesSubplot:xlabel='Actual Values', ylabel='Predicted Values'>

# %%
#xgboost
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
X = lrDf[['HostID','Neighbourhood','Latitude','Longtitude','RoomType','MinNights','NumReviews','RoomsPerHost','Availibility']]
y = lrDf['Price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0,2],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3]
        }
xgb = XGBRegressor()
rs = RandomizedSearchCV(xgb, param_distributions=params, n_iter=5, n_jobs=4, cv=5, verbose=3, random_state=1001 )
rs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    2.1s finished
# [16:59:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=5, estimator=XGBRegressor(), n_iter=5, n_jobs=4,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'max_depth': [3],
#                                         'min_child_weight': [1, 5, 10],
#                                         'subsample': [0.6, 0.8, 1.0, 2]},
#                    random_state=1001, verbose=3)

# %%
y_pred0 = rs.best_estimator_.predict(X_train)
y_pred = rs.best_estimator_.predict(X_test)
print(np.sqrt(mean_squared_error(y_train, y_pred0)))
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 9029.006084682647
# 8937.778685476056

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
rmse = np.sqrt(np.mean(y_pred - y_test)**2)
print('rmse: ', rmse)

r2 = r2_score(y_test, y_pred)
print('r2 score: ', r2)
# Out:
# rmse:  229.39167841126897
# r2 score:  0.4458855948481536

# %%
xgBoostPred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y_pred})
xgBoostPred.head(30)
# Out:
#     Actual Values  Predicted Values
# 0             952       1655.768433
# 1            1407       1943.869385
# 2             690       1851.930908
# 3            8893       5153.080566
# 4           12024       4864.846680
# 5            1881       5983.590820
# 6            1357       3728.747803
# 7             500       2296.852295
# 8            1192       2155.895752
# 9            1190       1996.531616
# 10           2476       7452.459961
# 11           9357       3999.196045
# 12           1071       2845.172119
# 13           1881       4107.285156
# 14           1071        661.613953
# 15           2667       7598.279785
# 16           1192       2607.294189
# 17           3004       5158.891113
# 18            619       1705.196045
# 19            762       1211.703369
# 20           1119       2585.030029
# 21           4006       4200.667969
# 22           2289       2547.447998
# 23           1190       4027.695068
# 24            787       2131.380127
# 25           2143       7855.979492
# 26            786       3351.379639
# 27           1333       1168.428467
# 28           2595       4780.438477
# 29            714       2208.441406

# %%
from matplotlib import pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel('Skutečná cena')
plt.ylabel('Predikováná cena')
z = np.polyfit(y_test, y_pred, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='red')
plt.show()

# %%
#Random forest
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
x = limitedDf[['Neighbourhood','Latitude','Longtitude','RoomType','MinNights','NumReviews','RoomsPerHost','Availibility']]
y = limitedDf['Price']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)
model=regressor.fit(x, y)  
y1 = model.predict(X_test)

# %%
rmse = np.sqrt(np.mean(y1 - y_test)**2)
print('rmse: ', rmse)

r2 = r2_score(y_test, y1)
print('r2 score: ', r2)
# Out:
# rmse:  26.241486761710792
# r2 score:  0.9288985171777978

# %%
rfPred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y1})
rfPred.head(30)
# Out:
#     Actual Values  Predicted Values
# 0             238           1014.97
# 1            1357           1397.40
# 2            2691           2612.73
# 3           10396           8997.10
# 4            1071           1331.49
# 5            1024           1099.56
# 6            2599           2087.99
# 7             500            528.36
# 8            1333           1620.79
# 9            4268           3668.34
# 10          13357          12112.07
# 11           1311           1407.73
# 12           9881           6476.79
# 13            524           1654.95
# 14           1335           1292.00
# 15           1119           1069.60
# 16           4548           3874.32
# 17           2048           2031.54
# 18            500            804.35
# 19           5000           4721.65
# 20           4000           3653.66
# 21           2691           2636.22
# 22           1810           2549.09
# 23           2143           1825.35
# 24           2429           1781.05
# 25           2405           2374.89
# 26            644            950.61
# 27           1884           1759.30
# 28           1190           1888.31
# 29           1192           1110.77

# %%
sns.residplot(x=rfPred['Actual Values'],y=rfPred['Predicted Values'])
# Out:
# <AxesSubplot:xlabel='Actual Values', ylabel='Predicted Values'>

# %%
from matplotlib import pyplot as plt
plt.scatter(y_test, y1)
plt.xlabel('Skutečná cena')
plt.ylabel('Predikováná cena')
z = np.polyfit(y_test, y1, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='red')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from keras import Sequential
from keras import layers
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import tensorflow as tf
import os
import collections
from matplotlib import pyplot as plt
def RMSE(Y,YHAT):
    return np.sqrt(mean_squared_error(Y,YHAT))
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

df = pd.read_csv('ReadyPragAirBnB.csv',sep=';', index_col=0)
df.head(5)
# Out:
#      RoomID                                             Name     HostID  \
# 0  25092602   ❤️AMAZING APARTMENT WITH NETFLIX NEAR CENTRE❤️  189676842
# 1  25197350    Room in beautiful area close to Prague Castle   28365945
# 2  25470062         Luxury apartment in the center of Prague   47717433
# 3  25547218      Much More For Your Money In Beautiful Letná   21217319
# 4  25907826  Apartment near city transport and Prague center  119497941
#
#   Neighbourhood         RoomType  Price  MinNights  NumReviews  RoomsPerHost  \
# 0       Praha 3  Entire home/apt   1310          1          79             1
# 1       Praha 6     Private room    763          1           2             1
# 2       Praha 2  Entire home/apt   1071          2          84             1
# 3       Praha 7  Entire home/apt   2074          1          21             1
# 4       Praha 4  Entire home/apt   2504          1          16             1
#
#    Availibility                         Location   Latitude  Longtitude  \
# 0           172  Czech republic, Prague, Praha 3  50.086376   14.444495
# 1             0  Czech republic, Prague, Praha 6  50.083104   14.369196
# 2           109  Czech republic, Prague, Praha 2  50.073298   14.439128
# 3             0  Czech republic, Prague, Praha 7  50.102008   14.417981
# 4             0  Czech republic, Prague, Praha 4  50.057750   14.450172
#
#   PriceCategory
# 0         nízká
# 1         nízká
# 2         nízká
# 3       střední
# 4       střední

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
##Lineární regrese
prepDf = pd.DataFrame(data=df)
prepDf.drop(['Name','RoomID','Location','Price'],axis=1,inplace=True)




le = preprocessing.LabelEncoder()
le.fit(prepDf['Neighbourhood'])
prepDf['Neighbourhood']=le.transform(prepDf['Neighbourhood'])

le = preprocessing.LabelEncoder()
le.fit(prepDf['RoomType'])
prepDf['RoomType']=le.transform(prepDf['RoomType'])


prepDf.head()
# Out:
#       HostID  Neighbourhood  RoomType  MinNights  NumReviews  RoomsPerHost  \
# 0  189676842             31         0          1          79             1
# 1   28365945             34         2          1           2             1
# 2   47717433             27         0          2          84             1
# 3   21217319             35         0          1          21             1
# 4  119497941             32         0          1          16             1
#
#    Availibility   Latitude  Longtitude PriceCategory
# 0           172  50.086376   14.444495         nízká
# 1             0  50.083104   14.369196         nízká
# 2           109  50.073298   14.439128         nízká
# 3             0  50.102008   14.417981       střední
# 4             0  50.057750   14.450172       střední

# %%
X = prepDf[['Neighbourhood','Latitude','Longtitude','RoomType','MinNights','NumReviews','RoomsPerHost','Availibility']]
y = prepDf['PriceCategory']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
##knn

from sklearn.neighbors import KNeighborsClassifier


knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train,y_train)

y_pred=knn.predict(X_test)

# %%
knnPred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y_pred})
knnPred.head(30)
# Out:
#    Actual Values Predicted Values
# 0        střední            nízká
# 1          nízká         nejvyšší
# 2       nejvyšší         nejvyšší
# 3          nízká            nízká
# 4        střední          střední
# 5          nízká            nízká
# 6          nízká            nízká
# 7         vysoká           vysoká
# 8        střední            nízká
# 9       nejvyšší            nízká
# 10        vysoká         nejvyšší
# 11       střední          střední
# 12      nejvyšší         nejvyšší
# 13         nízká            nízká
# 14         nízká            nízká
# 15         nízká            nízká
# 16       střední          střední
# 17       střední          střední
# 18       střední            nízká
# 19         nízká            nízká
# 20         nízká            nízká
# 21         nízká            nízká
# 22         nízká            nízká
# 23         nízká          střední
# 24         nízká            nízká
# 25       střední          střední
# 26        vysoká            nízká
# 27       střední         nejvyšší
# 28       střední          střední
# 29       střední          střední

# %%
from sklearn.metrics import accuracy_score
knnScore = accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)
print('knnScore :', knnScore*100,'%')
# Out:
# knnScore : 72.06526064464784 %

# %%
#naiveBayes
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train);

y_pred = model.predict(X_test)

# %%
naiveBayesPred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y_pred})
naiveBayesPred.head(30)
# Out:
#    Actual Values Predicted Values
# 0        střední          střední
# 1          nízká            nízká
# 2       nejvyšší           vysoká
# 3          nízká          střední
# 4        střední            nízká
# 5          nízká          střední
# 6          nízká            nízká
# 7         vysoká            nízká
# 8        střední          střední
# 9       nejvyšší          střední
# 10        vysoká          střední
# 11       střední            nízká
# 12      nejvyšší         nejvyšší
# 13         nízká          střední
# 14         nízká          střední
# 15         nízká          střední
# 16       střední          střední
# 17       střední           vysoká
# 18       střední            nízká
# 19         nízká            nízká
# 20         nízká          střední
# 21         nízká            nízká
# 22         nízká            nízká
# 23         nízká            nízká
# 24         nízká          střední
# 25       střední          střední
# 26        vysoká            nízká
# 27       střední          střední
# 28       střední          střední
# 29       střední          střední

# %%
naiveBayesScore = accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)
print('naiveBayesScore :', naiveBayesScore*100,'%')
# Out:
# naiveBayesScore : 57.34182252288102 %

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='liblinear', random_state=0).fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
logRegPred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y_pred})
logRegPred.head(30)
# Out:
#    Actual Values Predicted Values
# 0        střední          střední
# 1          nízká            nízká
# 2       nejvyšší          střední
# 3          nízká          střední
# 4        střední            nízká
# 5          nízká          střední
# 6          nízká            nízká
# 7         vysoká            nízká
# 8        střední          střední
# 9       nejvyšší            nízká
# 10        vysoká          střední
# 11       střední          střední
# 12      nejvyšší          střední
# 13         nízká          střední
# 14         nízká          střední
# 15         nízká          střední
# 16       střední          střední
# 17       střední          střední
# 18       střední            nízká
# 19         nízká            nízká
# 20         nízká          střední
# 21         nízká            nízká
# 22         nízká            nízká
# 23         nízká            nízká
# 24         nízká          střední
# 25       střední          střední
# 26        vysoká            nízká
# 27       střední          střední
# 28       střední            nízká
# 29       střední          střední

# %%
logRegScore = accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)
print('logRegScore :', logRegScore*100,'%')
# Out:
# logRegScore : 57.938718662952645 %

# %%
#decTree
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()
model=dtree.fit(X_train,y_train)
y_predTree = model.predict(X_test)

# %%
decTreePred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y_predTree})
decTreePred.head(20)
# Out:
#    Actual Values Predicted Values
# 0        střední          střední
# 1          nízká          střední
# 2       nejvyšší         nejvyšší
# 3          nízká            nízká
# 4        střední         nejvyšší
# 5          nízká            nízká
# 6          nízká            nízká
# 7         vysoká           vysoká
# 8        střední          střední
# 9       nejvyšší          střední
# 10        vysoká          střední
# 11       střední         nejvyšší
# 12      nejvyšší         nejvyšší
# 13         nízká            nízká
# 14         nízká          střední
# 15         nízká            nízká
# 16       střední           vysoká
# 17       střední          střední
# 18       střední            nízká
# 19         nízká            nízká

# %%
decTreeScore = accuracy_score(y_test, y_predTree, normalize=True, sample_weight=None)
print('decTreeScore :', decTreeScore*100,'%')
# Out:
# decTreeScore : 57.938718662952645 %

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier

from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# prepare the cross-validation procedure
cv = KFold(n_splits=10, random_state=1, shuffle=True)
# create model

classifier = RandomForestClassifier(n_estimators = 250, random_state = 0)

model=classifier.fit(X_train, y_train)  
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), max(scores)))


y_pred = model.predict(X_test)
# Out:
# Accuracy: 0.681 (0.695)

# %%
ranForPred = pd.DataFrame({
        'Actual Values': np.array(y_test).flatten(),
        'Predicted Values': y_pred})
ranForPred.head(30)
# Out:
#    Actual Values Predicted Values
# 0        střední          střední
# 1          nízká            nízká
# 2       nejvyšší         nejvyšší
# 3          nízká            nízká
# 4        střední            nízká
# 5          nízká            nízká
# 6          nízká            nízká
# 7         vysoká           vysoká
# 8        střední          střední
# 9       nejvyšší          střední
# 10        vysoká          střední
# 11       střední          střední
# 12      nejvyšší         nejvyšší
# 13         nízká            nízká
# 14         nízká            nízká
# 15         nízká          střední
# 16       střední          střední
# 17       střední          střední
# 18       střední            nízká
# 19         nízká            nízká
# 20         nízká            nízká
# 21         nízká            nízká
# 22         nízká            nízká
# 23         nízká            nízká
# 24         nízká            nízká
# 25       střední            nízká
# 26        vysoká           vysoká
# 27       střední         nejvyšší
# 28       střední            nízká
# 29       střední          střední

# %%
ranForScore = accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)
print('ranForScore :', ranForScore*100,'%')
# Out:
# ranForScore : 67.80740151213689 %
